# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn
# %matplotlib inline

# %%
df.shape
# Out:
# (400, 27)

# %%
df = pd.read_csv(r'C:\Users\Dell Latitude 7410\Downloads\ML-Dataset.csv')
df
# Out:
#         RegionName               CountryName        State       City  \
# 0    South America  United States of America        Texas  Southlake
# 1    South America  United States of America        Texas  Southlake
# 2    South America  United States of America        Texas  Southlake
# 3    South America  United States of America        Texas  Southlake
# 4    South America  United States of America        Texas  Southlake
# ..             ...                       ...          ...        ...
# 395           Asia                     India  Maharashtra     Bombay
# 396           Asia                     India  Maharashtra     Bombay
# 397           Asia                     India  Maharashtra     Bombay
# 398           Asia                     India  Maharashtra     Bombay
# 399           Asia                     India  Maharashtra     Bombay
#
#     PostalCode     WarehouseAddress    WarehouseName     EmployeeName  \
# ...

# %%
df.describe()
# Out:
#        EmployeePhone  ProductStandardCost       Profit  ProductListPrice  \
# count   4.000000e+02           400.000000   400.000000        400.000000
# mean    1.300551e+12          1812.654525   189.743700       2002.398800
# std     3.546655e+12          4297.988742   254.318871       4432.591249
# min     1.856490e+07            12.630000     0.000000         15.550000
# 25%     9.716165e+08           414.160000    59.972500        502.982500
# 50%     1.168870e+10           698.320000   134.200000        849.990000
# 75%     2.651186e+10          1671.950000   229.520000       1999.890000
# max     1.144164e+13         75410.000000  2770.000000      78180.000000
#
#        CustomerCreditLimit  CustomerPhone  PerUnitPrice  TotalItemQuantity
# count           400.000000   4.000000e+02    400.000000         400.000000
# mean           2033.617500   6.422348e+10    839.253100         123.695000
# std            1534.488065   1.871854e+11    706.449917          67.438876
# ...

# %%
df.isnull().sum()
# Out:
# RegionName             0
# CountryName            0
# State                  0
# City                   0
# PostalCode             0
# WarehouseAddress       0
# WarehouseName          0
# EmployeeName           0
# EmployeeEmail          0
# EmployeePhone          0
# EmployeeHireDate       0
# EmployeeJobTitle       0
# ProductName            0
# ProductDescription     0
# ProductStandardCost    0
# Profit                 0
# ProductListPrice       0
# CustomerName           0
# CustomerAddress        0
# CustomerCreditLimit    0
# CustomerEmail          0
# CustomerPhone          0
# Status                 0
# OrderDate              0
# Status.1               0
# PerUnitPrice           0
# TotalItemQuantity      0
# dtype: int64

# %% [markdown]
# df

# %%
seaborn.pairplot(df)
plt.show()

# %%
y = df['CustomerCreditLimit']
y
# Out:
# 0      5000
# 1      5000
# 2      1200
# 3      2400
# 4      1200
#        ...
# 395    4900
# 396    5000
# 397    4000
# 398    3000
# 399    2000
# Name: CustomerCreditLimit, Length: 400, dtype: int64

# %%
import sklearn.cluster as cluster

# %%
kmeans = cluster.KMeans(n_clusters = 4) # k = 4

# %%
kmeans = kmeans.fit(df[['CustomerCreditLimit','TotalItemQuantity']])
# Out:
# C:\Users\Dell Latitude 7410\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1419: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(

# %%
kmeans.cluster_centers_
# Out:
# array([[ 426.39830508,  135.60169492],
#        [4245.19230769,  125.78846154],
#        [2403.95238095,  106.14285714],
#        [1273.40425532,  122.11702128]])

# %%
df['clusters'] = kmeans.labels_

# %%
df['clusters']
# Out:
# 0      1
# 1      1
# 2      3
# 3      2
# 4      3
#       ..
# 395    1
# 396    1
# 397    1
# 398    2
# 399    2
# Name: clusters, Length: 400, dtype: int32

# %%
df.head(15)
# Out:
#        RegionName               CountryName  State       City PostalCode  \
# 0   South America  United States of America  Texas  Southlake      26192
# 1   South America  United States of America  Texas  Southlake      26192
# 2   South America  United States of America  Texas  Southlake      26192
# 3   South America  United States of America  Texas  Southlake      26192
# 4   South America  United States of America  Texas  Southlake      26192
# 5   South America  United States of America  Texas  Southlake      26192
# 6   South America  United States of America  Texas  Southlake      26192
# 7   South America  United States of America  Texas  Southlake      26192
# 8   South America  United States of America  Texas  Southlake      26192
# 9   South America  United States of America  Texas  Southlake      26192
# 10  South America  United States of America  Texas  Southlake      26192
# 11  South America  United States of America  Texas  Southlake      26192
# ...

# %%
df['clusters'].value_counts()
# Out:
# clusters
# 0    118
# 1    104
# 3     94
# 2     84
# Name: count, dtype: int64

# %%
seaborn.scatterplot(x ='CustomerCreditLimit', y='TotalItemQuantity', hue='clusters', data=df)
# Out:
# <Axes: xlabel='Number of clusters (K)', ylabel='Sum'>

# %%
from sklearn.cluster import KMeans

# %%
K_range = range(1,17)
wcss = []

# %%
for k in K_range:
    km = KMeans(n_clusters=k)
    km.fit(df[['CustomerCreditLimit','TotalItemQuantity']])
    wcss.append(km.inertia_)  #Inertia_ is the sum of squared error for each cluster.
# Out:
# C:\Users\Dell Latitude 7410\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1419: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# C:\Users\Dell Latitude 7410\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1419: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# C:\Users\Dell Latitude 7410\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1419: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# ...

# %%
wcss
# Out:
# [941321447.2674999,
#  246529264.48669758,
#  106369144.98973745,
#  59467043.00432597,
#  17984495.07988619,
#  14920548.95046375,
#  11424822.974426735,
#  9224654.091910701,
#  7617586.042215733,
#  5697086.827352826,
#  5428050.57199649,
#  4095601.7921867217,
#  3924597.728611389,
#  3702978.238598967,
#  3425341.6031224923,
#  3043714.695170328]

# %%
plt.xlabel('Number of clusters (K)') 
plt.ylabel('Sum of squared error') 
plt.plot(K_range,wcss) 
plt.title('credit')
# Out:
# Text(0.5, 1.0, 'credit')

# %%
K_range = range(1,20)
wcss2 = []

# %%
for k in K_range:
    km = KMeans(n_clusters=k)
    km.fit(df[['TotalItemQuantity']])
    wcss2.append(km.inertia_)
# Out:
# C:\Users\Dell Latitude 7410\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1419: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# C:\Users\Dell Latitude 7410\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1419: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# C:\Users\Dell Latitude 7410\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1419: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# ...

# %%
wcss2
# Out:
# [1814652.7899999996,
#  670273.4518012558,
#  183350.54731715168,
#  98144.24008510777,
#  80651.44690692487,
#  60324.11044667507,
#  46410.343545265125,
#  28941.96148203271,
#  25147.39200216769,
#  19594.817982062785,
#  13199.806649346096,
#  12298.25762100647,
#  10241.833487479173,
#  8551.714491198481,
#  6566.03338780601,
#  5731.703735174087,
#  4731.240670817746,
#  3932.5261906367014,
#  3840.259854787385]

# %%
plt.xlabel('Number of clusters (K)')
plt.ylabel('Sum of squared error')
plt.plot(K_range,wcss2)

# %%
kmeans2 = cluster.KMeans(n_clusters = 4)

# %%
kmeans2 = kmeans2.fit(df[['TotalItemQuantity']])
# Out:
# C:\Users\Dell Latitude 7410\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1419: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(

# %%
kmeans2.cluster_centers_
# Out:
# array([[ 19.75903614],
#        [197.51879699],
#        [131.47474747],
#        [100.61176471]])

# %%
df['TotalItemQuantity_clusters'] = kmeans2.labels_

# %%
df['TotalItemQuantity_clusters'].value_counts()
# Out:
# TotalItemQuantity_clusters
# 1    133
# 2     99
# 3     85
# 0     83
# Name: count, dtype: int64

# %%
seaborn.scatterplot(x='CustomerCreditLimit', y='TotalItemQuantity',hue='TotalItemQuantity_clusters',data=df)
# Out:
# <Axes: title={'center': 'credit'}, xlabel='Number of clusters (K)', ylabel='Sum of squared error'>
