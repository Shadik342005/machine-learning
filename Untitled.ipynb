# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(0, 5, 15)
y = x**2

# %%
x
# Out:
# array([0.        , 0.35714286, 0.71428571, 1.07142857, 1.42857143,
#        1.78571429, 2.14285714, 2.5       , 2.85714286, 3.21428571,
#        3.57142857, 3.92857143, 4.28571429, 4.64285714, 5.        ])

# %%
y
# Out:
# array([ 0.        ,  0.12755102,  0.51020408,  1.14795918,  2.04081633,
#         3.18877551,  4.59183673,  6.25      ,  8.16326531, 10.33163265,
#        12.75510204, 15.43367347, 18.36734694, 21.55612245, 25.        ])

# %%
plt.plot(x, y)
plt.show()

# %%
plt.xlabel('X axis')
plt.ylabel('Y axis')
plt.title('Graph of $y = x^4$')

plt.plot(x, y)
plt.show()

# %%
x1 = np.linspace(-np.pi, np.pi, 356)
x2 = np.linspace(-np.pi, np.pi, 356)

y1 = np.cos(x1)
y2 = np.sin(x2)

# %%
plt.plot(x1, y1, x2, y2)
plt.show()

# %%
plt.figure(figsize = (10, 8), dpi = 120)

plt.plot(x1, y1)
plt.plot(x2, y2)

plt.show()

# %%
plt.figure(figsize = (10, 8), dpi = 80)

plt.plot(x1, y1, 'r-^')
plt.plot(x2, y2, 'b-*')

plt.show()

# %%
plt.figure(figsize = (10, 6), dpi = 80)

plt.plot(x1, y1, color = 'blue')
plt.plot(x2, y2, color = 'yellow')

plt.show()

# %%
plt.figure(figsize = (10, 6), dpi = 80)

plt.plot(x1, y1, color = 'blue', lw = 3.5)
plt.plot(x2, y2, color = 'yellow', lw = 3.5)

plt.show()

# %%
plt.figure(figsize = (10, 6), dpi = 80)

plt.plot(x1, y1, color = 'blue', lw = 3.5, ls = '--')
plt.plot(x2, y2, color = 'yellow', lw = 3.5, ls = '-.')

plt.show()

# %%
plt.figure(figsize = (10, 6), dpi = 80)

plt.plot(x1, y1, color = 'blue', lw = 3.5, ls = '--')
plt.plot(x2, y2, color = 'yellow', lw = 3.5, ls = '-.')

plt.xticks([-np.pi, -np.pi/2, 0, np.pi/2, np.pi])
plt.yticks([-1, 0, 1])

plt.show()

# %%
plt.figure(figsize = (10, 6), dpi = 80)

plt.plot(x1, y1, color = 'blue', lw = 3.5, ls = '--')
plt.plot(x2, y2, color = 'yellow', lw = 3.5, ls = '-.')

plt.xticks([-np.pi, -np.pi/2, 0, np.pi/2, np.pi], [r'$-\pi$', r'$-\pi/2$', r'$0$',r'$\pi/2$',r'$\pi$'])
plt.yticks([-1, 0, 1])

plt.show()

# %%
plt.figure(figsize = (10,6), dpi = 80)

plt.plot([1,2,3,4,5], [1,4,9,16, 25], color = 'green', lw = 3.5, marker = '^', mec = 'black', mew = 8)

plt.show()

# %%
x = np.random.randint(100, size = 50)

y = np.random.randint(100, size = 50)

# %%
plt.scatter(x, y, marker = '*')

# %%
fig = plt.figure(figsize = (10, 6))

ax = plt.axes(projection = '3d')

x = np.random.randint(100, size = 200)
y = np.random.randint(100, size = 200)
z = np.random.randint(100, size = 200)

ax.scatter3D(x, y, z, c = 'black')

# %%
def f(x, y):
    return np.sin(np.sqrt(x**2+y**2))

# %%
r = np.linspace(0, 6, 20)
theta = np.linspace(-0.9*np.pi, 0.8*np.pi, 40)

r,theta = np.meshgrid(r, theta)

X = r*np.sin(theta)
Y = r*np.cos(theta)
Z = f(X,Y)

# %%
fig = plt.figure(figsize = (10, 6))

ax = plt.axes(projection = '3d')

ax.plot_surface(X, Y, Z, cmap = 'summer')

plt.show()

# %%
ax.view_init(60, 0)
fig

# %%
fig.savefig('test.pdf', dpi = 200)
